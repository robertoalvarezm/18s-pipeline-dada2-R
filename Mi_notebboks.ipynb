# %% [markdown]
# <a href="https://colab.research.google.com/github/robertoalvarezm/18s-pipeline-dada2-R/blob/master/Mi_notebboks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x<-3

x<-rnorm(1000)
hist(x)
library(ggplot2)
# Out:
# Plot with title “Histogram of x”

# %% [markdown]
# **Esta es una nueva sección**

# %%
x<-3
